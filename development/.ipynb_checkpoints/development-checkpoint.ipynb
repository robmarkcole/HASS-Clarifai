# %% [markdown]
# * https://www.clarifai.com/developer/guide/
# * https://github.com/Clarifai/clarifai-python
#
# `pip install clarifai --upgrade`
# Version 2.2.3

# %%
from clarifai.rest import ClarifaiApp
import requests as rq
import os
import io
import base64
from PIL import Image
import json
import matplotlib.pyplot as plt
import matplotlib.patches as patches
# %matplotlib inline
import sys
print(sys.version)

def load_api_secrets(filename):
    """Convenience to load the API key from a json file."""
    try:
        with open(filename, 'r') as fp:
            api_params = json.load(fp)
    except Exception as e:
        print('Failed to load API secrets key: {}'.format(e))
        api_params = None
    return api_params['key']


def encode_image(image):
    """base64 encode an image stream."""
    base64_img = base64.b64encode(image)
    return base64_img
# Out:
# 3.6.5 |Anaconda, Inc.| (default, Apr 26 2018, 08:42:37)
# [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]

# %% [markdown]
# ## API key
# https://clarifai-python.readthedocs.io/en/latest/install/#configuration
#
# api_key can be passed to the constructor (https://clarifai-python.readthedocs.io/en/latest/clarifai.rest/#clarifai.rest.client.ClarifaiApp), or set as an environment variable.

# %%
API_key_filepath = 'Clarifai_API_key.json'
API_key = load_api_secrets(API_key_filepath)
API_key
# Out:
# '123456'

# %% [markdown]
# To load my private key from desktop

# %%
API_key_filepath = '/Users/robincole/Desktop/Clarifai_API_key.json'
API_key = load_api_secrets(API_key_filepath)
#API_key

# %%
app = ClarifaiApp(api_key=API_key)  # the constructor with api_key
#app = ClarifaiApp()  # the constructor with api_key as an environment variable

# %%
# List all models
for model in app.models.get_all():
    print(model.model_name)
# Out:
# pets
# Portrait Quality
# Landscape Quality
# Textures & Patterns
# moderation
# logo
# focus
# demographics
# apparel
# celeb-v1.3
# face-v1.3
# face-v1.3
# weddings-v1.0
# travel-v1.0
# nsfw-v1.0
# food-items-v1.0
# general-v1.3
# color
# general-v1.3

# %%
general_model = app.models.get('general-v1.3')

# %%
file_name = '/Users/robincole/Pictures/monkey.jpg'

# %%
img = plt.imread(file_name)  # Creates an ndarray
plt.imshow(img)
plt.show()

# %% [markdown]
# Predict by base 64 encoded image

# %%
with open(file_name, "rb") as image_file:
    #encoded_string = base64.b64encode(image_file.read())
    encoded_string = encode_image(image_file.read())

# %%
def parse_concepts(api_concepts):
    """Parse the API concepts data."""
    return {concept['name']: round(100.0*concept['value'], 2) 
            for concept in api_concepts}

# %%
# %%time
response = general_model.predict_by_base64(encoded_string)

api_concepts = response['outputs'][0]['data']['concepts']
print(len(api_concepts))
for concept in api_concepts:
    print(concept)
# Out:
# 20
# {'id': 'ai_QhfgX2RS', 'name': 'monkey', 'value': 0.9989439, 'app_id': 'main'}
# {'id': 'ai_cklw8zCB', 'name': 'primate', 'value': 0.99636483, 'app_id': 'main'}
# {'id': 'ai_fbqvMwRm', 'name': 'wildlife', 'value': 0.9954382, 'app_id': 'main'}
# {'id': 'ai_N6BnC4br', 'name': 'mammal', 'value': 0.98672926, 'app_id': 'main'}
# {'id': 'ai_HDqK5lNg', 'name': 'wild', 'value': 0.9794917, 'app_id': 'main'}
# {'id': 'ai_zGTNPK2n', 'name': 'jungle', 'value': 0.979002, 'app_id': 'main'}
# {'id': 'ai_tBcWlsCp', 'name': 'nature', 'value': 0.97729456, 'app_id': 'main'}
# {'id': 'ai_4CRlSvbV', 'name': 'cute', 'value': 0.9717134, 'app_id': 'main'}
# {'id': 'ai_R67cVW5t', 'name': 'sit', 'value': 0.9681964, 'app_id': 'main'}
# {'id': 'ai_HhDFdrkp', 'name': 'ape', 'value': 0.96803015, 'app_id': 'main'}
# {'id': 'ai_HkqZwBbr', 'name': 'little', 'value': 0.96734583, 'app_id': 'main'}
# {'id': 'ai_786Zr311', 'name': 'no person', 'value': 0.96688616, 'app_id': 'main'}
# {'id': 'ai_SzsXMB1w', 'name': 'animal', 'value': 0.96678984, 'app_id': 'main'}
# {'id': 'ai_zFnPQdgB', 'name': 'wood', 'value': 0.95728415, 'app_id': 'main'}
# {'id': 'ai_bBl132T0', 'name': 'zoo', 'value': 0.9516171, 'app_id': 'main'}
# {'id': 'ai_wqgGDjK4', 'name': 'fur', 'value': 0.9498426, 'app_id': 'main'}
# {'id': 'ai_Pbd3f6g8', 'name': 'tropical', 'value': 0.9430005, 'app_id': 'main'}
# {'id': 'ai_5mgGJnNc', 'name': 'baby', 'value': 0.93533516, 'app_id': 'main'}
# {'id': 'ai_Zmhsv0Ch', 'name': 'outdoors', 'value': 0.93093574, 'app_id': 'main'}
# {'id': 'ai_BLhsF4s6', 'name': 'tail', 'value': 0.9139317, 'app_id': 'main'}
# CPU times: user 10.2 ms, sys: 2.48 ms, total: 12.6 ms
# Wall time: 1.57 s

# %%
parse_concepts(api_concepts)
# Out:
# {'monkey': 99.89,
#  'primate': 99.64,
#  'wildlife': 99.54,
#  'mammal': 98.67,
#  'wild': 97.95,
#  'jungle': 97.9,
#  'nature': 97.73,
#  'cute': 97.17,
#  'sit': 96.82,
#  'ape': 96.8,
#  'little': 96.73,
#  'no person': 96.69,
#  'animal': 96.68,
#  'wood': 95.73,
#  'zoo': 95.16,
#  'fur': 94.98,
#  'tropical': 94.3,
#  'baby': 93.53,
#  'outdoors': 93.09,
#  'tail': 91.39}

# %% [markdown]
# Predict by filename

# %%
# %%time
response = general_model.predict_by_filename(filename=file_name)
# Out:
# CPU times: user 15 ms, sys: 4 ms, total: 19 ms
# Wall time: 1.63 s

# %%
response['outputs'][0]['data']['concepts'][0]
# Out:
# {'id': 'ai_QhfgX2RS', 'name': 'monkey', 'value': 0.9989439, 'app_id': 'main'}
